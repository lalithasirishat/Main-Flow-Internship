# %%
import pandas as pd
# Step 1: Load the CSV file into a DataFrame
df = pd.read_csv('01.Data Cleaning and Preprocessing.csv')
# Step 2: Display the DataFrame
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.columns.tolist() #Columns of the dataset
# Out:
# ['Observation',
#  'Y-Kappa',
#  'ChipRate',
#  'BF-CMratio',
#  'BlowFlow',
#  'ChipLevel4 ',
#  'T-upperExt-2 ',
#  'T-lowerExt-2  ',
#  'UCZAA',
#  'WhiteFlow-4 ',
#  'AAWhiteSt-4 ',
#  'AA-Wood-4  ',
#  'ChipMoisture-4 ',
#  'SteamFlow-4 ',
#  'Lower-HeatT-3',
#  'Upper-HeatT-3 ',
#  'ChipMass-4 ',
#  'WeakLiquorF ',
#  'BlackFlow-2 ',
#  'WeakWashF ',
#  'SteamHeatF-3 ',
#  'T-Top-Chips-4 ',
#  'SulphidityL-4 ']

# %%
df.isnull().sum() #Number of null values in each column
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
df.nunique() #Number of unique values in each column
# Out:
# Observation        301
# Y-Kappa            216
# ChipRate           243
# BF-CMratio         286
# BlowFlow           286
# ChipLevel4         291
# T-upperExt-2       286
# T-lowerExt-2       282
# UCZAA              172
# WhiteFlow-4        294
# AAWhiteSt-4         99
# AA-Wood-4          208
# ChipMoisture-4     286
# SteamFlow-4        292
# Lower-HeatT-3      292
# Upper-HeatT-3      298
# ChipMass-4         291
# WeakLiquorF        295
# BlackFlow-2        296
# WeakWashF          275
# SteamHeatF-3       298
# T-Top-Chips-4      258
# SulphidityL-4      129
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100  #Percentage of missing values in each column
# Out:
# Observation         0.000000
# Y-Kappa             0.000000
# ChipRate            1.543210
# BF-CMratio          5.246914
# BlowFlow            4.938272
# ChipLevel4          0.308642
# T-upperExt-2        0.617284
# T-lowerExt-2        0.617284
# UCZAA               7.716049
# WhiteFlow-4         0.308642
# AAWhiteSt-4        46.604938
# AA-Wood-4           0.308642
# ChipMoisture-4      0.308642
# SteamFlow-4         0.308642
# Lower-HeatT-3       0.617284
# Upper-HeatT-3       0.617284
# ChipMass-4          0.308642
# WeakLiquorF         0.308642
# BlackFlow-2         0.617284
# WeakWashF           0.308642
# SteamHeatF-3        0.617284
# T-Top-Chips-4       0.308642
# SulphidityL-4      46.604938
# dtype: float64

# %%
# Step 3: Filter data based on conditions
filtered_df = df[df['ChipRate'] > 50] #Filter rows where 'ChipRate' > 50
print(filtered_df.head())
filtered_df_2 = df[df['BlowFlow'] < 100] #Filter rows where 'BlowFlow' < 100
print(filtered_df_2.head())
# Out:
# Empty DataFrame
# Columns: [Observation, Y-Kappa, ChipRate, BF-CMratio, BlowFlow, ChipLevel4 , T-upperExt-2 , T-lowerExt-2  , UCZAA, WhiteFlow-4 , AAWhiteSt-4 , AA-Wood-4  , ChipMoisture-4 , SteamFlow-4 , Lower-HeatT-3, Upper-HeatT-3 , ChipMass-4 , WeakLiquorF , BlackFlow-2 , WeakWashF , SteamHeatF-3 , T-Top-Chips-4 , SulphidityL-4 ]
# Index: []
#
# [0 rows x 23 columns]
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 182     7-13:00    23.83    14.227         NaN       0.0      220.074
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 182        352.981         323.718  1.416        594.97  ...        62.476
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 182        321.062         296.846      158.196       977.152      1092.896
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 182      81.065         51.821         249.353             NaN
#
# [1 rows x 23 columns]

# %%
# Step 4: Handle missing values
# Remove rows with missing values
df_cleaned = df.dropna()
print(df_cleaned.head())
# Fill missing values with 0
df_filled = df.fillna(0)
print(df_filled.head())
# Fill missing values in 'ChipRate' with the mean of 'ChipRate'
df['ChipRate'] = df['ChipRate'].fillna(df['ChipRate'].mean())
print(df.head())
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5     1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9    31-08:00    24.70    13.850      96.208  1334.892      362.511
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 5        344.014         325.195  1.436       628.245  ...        65.225
# 7        352.321         331.162  1.468       625.549  ...        71.298
# 9        352.372         327.358  1.515       553.172  ...        64.249
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
# Step 5: Calculate summary statistics
summary = df.describe()
print(summary)
# Specific statistics
mean_chiprate = df['ChipRate'].mean()
median_chiprate = df['ChipRate'].median()
std_chiprate = df['ChipRate'].std()
print(f"Mean ChipRate: {mean_chiprate}")
print(f"Median ChipRate: {median_chiprate}")
print(f"Standard Deviation of ChipRate: {std_chiprate}")
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...
